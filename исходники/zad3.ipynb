# %% [markdown]
# # Лабораторная работа 1
# #### Цель: Реализовать методы сортировки строк числовой матрицы в соответствии с заданием. Оценить время работы каждого алгоритма сортировки и сравнить его со временем стандартной функции сортировки. Испытания проводить на сгенерированных матрицах.

# %%
import random
import time
m = input() 
n = input()
min_limit = input()
max_limit = input()

# %%
def selection_sort(j):
    for A in j:
        for i in range(len(A)):
            A[A[i:].index(min(A[i:])) + i],A[i] = A[i], min(A[i:])
    return j

def insertion_sort(a):
    for A in a:
        for i in range(1,len(A)):
            q=A[i]
            j=i-1
            while(j>=0 and A[j]>q):
                A[j + 1] = A[j]
                j=j-1
            A[j+1]=q
    return(a)

def bubble_sort(a):
    for A in a:
        for i in range(len(A)-1):
            c = 0
            for j in range(len(A)-1-i):
                if (A[j]>A[j+1]):
                    c+=1
                    A[j],A[j+1] = A[j+1],A[j]
            if c == 0:
                break
    return a


def shell(a):
    for A in a:
        d = len(A) // 2
        while d:
            for i, el in enumerate(A[d:], d):
                while i >= d and A[i - d] > el:
                    A[i] = A[i - d]
                    i -= d
                A[i] = el
            d //= 2
    return a
def tour(a):
    for A in a:
        print()

def quick(a):
    i = 0
    for A in a:
        a[i] = qsort(A)
        i+=1
    return a
def qsort(array):
    if len(array) <=1:
        return array
    *unsort, Z = array
    low = qsort([i for i in unsort if i < Z])
    high = qsort([i for i in unsort if i >= Z])
    return low + [Z] + high

def maxHeap(a, n, i):
    largest = i
    l = 2 * i + 1
    r = 2 * i + 2
    if l < n and a[i] < a[l]:
        largest = l
    if r < n and a[largest] < a[r]:
        largest = r
    if largest != i:
        a[i],a[largest] = a[largest],a[i]
        maxHeap(a, n, largest)
def heap(a):
    for A in a:
        for i in range(len(A), -1, -1):
            maxHeap(A, len(A), i)
        for i in range(len(A) - 1, 0, -1):
            A[i], A[0] = A[0], A[i]
            maxHeap(A, i, 0)
    return a

# %%
if (m == "" or  n == "" or min_limit == "" or max_limit == ""):
    m = 50
    n = 50
    min_limit = -250
    max_limit = 1007

# %%
x = [[random.randint(int(min_limit),int(max_limit) ) for a in range(int(m))] for k in range(int(n))]
print(x)
# Out:
# [[884, -66, 202, 87, 771, 725, 348, 953, -96, 853, 431, 577, 561, 438, 503, 362, 648, 368, 43, 528, 694, 747, 237, -224, 99, 343, 815, 344, -20, 503, 988, 116, 477, 54, 371, 199, -175, 909, 76, 48, 165, 512, -66, 427, 493, 445, 642, 679, -200, 718], [110, 975, 701, 86, -75, 499, 131, 414, 908, 1006, 747, 832, 443, 963, -11, 684, 142, 55, 307, 234, 321, 589, 323, 181, 415, 960, 616, 764, 435, 779, 337, 127, -41, 148, 289, 785, 450, 230, 124, 345, 709, 809, -111, 967, 508, 96, 416, 913, 123, -202], [-87, 639, 855, 520, 208, 608, 328, 925, 560, 882, 472, 144, 691, 386, 260, -119, -74, -88, 118, 213, 877, 1003, 311, 533, 75, 657, 785, 22, 341, 715, 372, 954, 69, 314, 343, 462, -200, 350, -156, 429, 562, -10, 131, 213, 364, 101, 988, 477, 857, 100], [681, 101, 461, 963, -95, -15, 325, 153, 316, 675, 475, 71, 200, -20, -105, 376, 407, -186, 548, 701, 549, -62, 585, 322, 187, -95, 727, -75, 512, 212, 694, 609, 291, 948, -222, -222, 874, 774, -118, 378, 516, 474, 473, 841, -29, 698, -187, 14
# ...

# %%
ui = x.copy()
# %timeit ui.sort()
# Out:
# 1.78 µs ± 140 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %%
ui = x.copy()
# %timeit selection_sort(ui)
# Out:
# 4.59 ms ± 247 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
ui = x.copy()
# %timeit insertion_sort(ui)
# Out:
# 391 µs ± 23.4 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
ui = x.copy()
# %timeit bubble_sort(ui)
# Out:
# 212 µs ± 13.7 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
ui = x.copy()
# %timeit shell(ui)
# Out:
# 1.6 ms ± 162 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
ui = x.copy()
# %timeit quick(ui)
# Out:
# 7.06 ms ± 445 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
ui = x.copy()
# %timeit heap(ui)
# Out:
# 7.06 ms ± 933 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
